# %% [markdown]
# # Mountain Car

# %%
import gym
import random
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
env = gym.make('MountainCar-v0')
env.reset()
# Out:
# array([-0.5301305,  0.       ], dtype=float32)

# %%
print('Action Space:', env.action_space)
print('Observation Space:', env.observation_space, '{')
print('\t Car position: min', env.observation_space.low[0], ' - max', env.observation_space.high[0] )
print('\t Car Velocity: min', env.observation_space.low[1], '- max', env.observation_space.high[1], '\n}')
# Out:
# Action Space: Discrete(3)
# Observation Space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32) {
# 	 Car position: min -1.2  - max 0.6
# 	 Car Velocity: min -0.07 - max 0.07
# }

# %%
# Define Q-learning function
def QLearning(env, learning, discount, epsilon, min_eps, episodes):
    # Determine size of discretized state space
    num_states = (env.observation_space.high - env.observation_space.low)*\
                    np.array([10, 100])
    num_states = np.round(num_states, 0).astype(int) + 1
    
    # Initialize Q table
    Q = np.random.uniform(low = -1, high = 1, 
                          size = (num_states[0], num_states[1], 
                                  env.action_space.n))
    
    # Initialize variables to track rewards
    reward_list = []
    ave_reward_list = []
    
    # Calculate episodic reduction in epsilon
    reduction = (epsilon - min_eps)/episodes
    
    # Run Q learning algorithm
    for i in range(episodes):
        # Initialize parameters
        done = False
        tot_reward, reward = 0,0
        state = env.reset()
        
        # Discretize state
        state_adj = (state - env.observation_space.low)*np.array([10, 100])
        state_adj = np.round(state_adj, 0).astype(int)
    
        while done != True:   
            # Render environment for last five episodes
            if i >= (episodes - 20):
                env.render()
                
            # Determine next action - epsilon greedy strategy
            if np.random.random() < 1 - epsilon:
                action = np.argmax(Q[state_adj[0], state_adj[1]]) 
            else:
                action = np.random.randint(0, env.action_space.n)
                
            # Get next state and reward
            state2, reward, done, info = env.step(action) 
            
            # Discretize state2
            state2_adj = (state2 - env.observation_space.low)*np.array([10, 100])
            state2_adj = np.round(state2_adj, 0).astype(int)
            
            #Allow for terminal states
            if done and state2[0] >= 0.5:
                Q[state_adj[0], state_adj[1], action] = reward
                
            # Adjust Q value for current state
            else:
                delta = learning*(reward + 
                                 discount*np.max(Q[state2_adj[0], 
                                                   state2_adj[1]]) - 
                                 Q[state_adj[0], state_adj[1],action])
                Q[state_adj[0], state_adj[1],action] += delta
                                     
            # Update variables
            tot_reward += reward
            state_adj = state2_adj
        
        # Decay epsilon
        if epsilon > min_eps:
            epsilon -= reduction
        
        # Track rewards
        reward_list.append(tot_reward)
        
        if (i+1) % 100 == 0:
            ave_reward = np.mean(reward_list)
            ave_reward_list.append(ave_reward)
            reward_list = []
            
        if (i+1) % 100 == 0:    
            print('Episode {} Average Reward: {}'.format(i+1, ave_reward))
            
    env.close()
    
    return ave_reward_list

# Run Q-learning algorithm
rewards = QLearning(env, 0.2, 0.9, 0.8, 0, 5000)

# Plot Rewards
plt.plot(100*(np.arange(len(rewards)) + 1), rewards)
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Average Reward vs Episodes')
plt.savefig('rewards.jpg')     
plt.close()
# Out:
# Episode 100 Average Reward: -200.0
# Episode 200 Average Reward: -200.0
# Episode 300 Average Reward: -200.0
# Episode 400 Average Reward: -200.0
# Episode 500 Average Reward: -200.0
# Episode 600 Average Reward: -200.0
# Episode 700 Average Reward: -200.0
# Episode 800 Average Reward: -200.0
# Episode 900 Average Reward: -200.0
# Episode 1000 Average Reward: -200.0
# Episode 1100 Average Reward: -200.0
# Episode 1200 Average Reward: -200.0
# Episode 1300 Average Reward: -200.0
# Episode 1400 Average Reward: -200.0
# Episode 1500 Average Reward: -200.0
# Episode 1600 Average Reward: -200.0
# Episode 1700 Average Reward: -200.0
# Episode 1800 Average Reward: -200.0
# Episode 1900 Average Reward: -200.0
# Episode 2000 Average Reward: -200.0
# Episode 2100 Average Reward: -200.0
# Episode 2200 Average Reward: -200.0
# Episode 2300 Average Reward: -200.0
# Episode 2400 Average Reward: -200.0
# Episode 2500 Average Reward: -200.0
# Episode 2600 Average Reward: -199.99
# Episode 2700 Average Reward: -200.0
# Episode 2800 Average Reward: -200.0
# Episode 2900 Average Reward: -199.27
# Episode 3000 Average Reward: -199.76
# Episode 3100 Average Reward: -200.0
# Episode 3200 Average Reward: -200.0
# Episode 3300 Average Reward: -199.42
# Episode 3400 Average Reward: -200.0
# Episode 3500 Average Reward: -199.14
# Episode 3600 Average Reward: -198.73
# Episode 3700 Average Reward: -198.63
# Episode 3800 Average Reward: -200.0
# Episode 3900 Average Reward: -199.31
# Episode 4000 Average Reward: -198.08
# Episode 4100 Average Reward: -197.11
# Episode 4200 Average Reward: -198.99
# Episode 4300 Average Reward: -197.93
# Episode 4400 Average Reward: -191.08
# Episode 4500 Average Reward: -194.84
# Episode 4600 Average Reward: -194.05
# Episode 4700 Average Reward: -190.38
# Episode 4800 Average Reward: -175.82
# Episode 4900 Average Reward: -188.65
# Episode 5000 Average Reward: -186.73

# %%
n_action = env.action_space.n
env_low = env.observation_space.low
env_high = env.observation_space.high
bins = 30 # number of states for discretization
def getState(state, env_low = env_low, env_high = env_high, bins = bins):
    """Returns the discretized position and velocity of an observation"""
    discretized_env = (env_high - env_low) / bins
    discretized_pos = int((state[0] - env_low[0]) / discretized_env[0])
    discretized_vel = int((state[1] - env_low[1]) / discretized_env[1])
    return discretized_pos, discretized_vel
n_eps = 100001 # number of episodes
alpha = 0.1 # learning rate
gamma = 0.9 # discount factor
epsilon = 0.2 # explore-exploit tradeoff factor
interval = 10000

# %%
def chooseAction(pos, vel, q_table, epsilon = epsilon):
    """Choose action based on an epsilon greedy strategy"""
    if random.random() < epsilon: # explore
        action = env.action_space.sample()
    else: # exploit
        action = np.argmax(q_table[pos][vel])
    return action

# %%
# establish q-table
q_table_sarsa = np.zeros((bins, bins, env.action_space.n))
# store reward
rewards_sarsa = []
# training
for ep in range(n_eps):
    
    current_reward = 0
    done = False
    state = env.reset()
    # discretize the state
    pos, vel = getState(state)
    # choose first action
    action = chooseAction(pos, vel, q_table_sarsa)
while not done:
        
        # render for the last 10 episodes
    if ep >= (n_eps - 10): 
        env.render()
            
        # next state
    next_state, reward, done, info = env.step(action)
# discretize the state
    next_pos, next_vel = getState(next_state)
        # next action
    next_action = chooseAction(next_pos, next_vel, q_table_sarsa)
    if done and next_state[0] >= env.goal_position:
        q_table_q[next_pos][next_vel][action] = reward
        
    else:
        # update Q value: Q(S, A) <-- Q(S, A) + alpha [R + gamma * Q(S', A') - Q(S, A)]
        q_table_sarsa[pos][vel][action] += \
        alpha * (reward + gamma * q_table_sarsa[next_pos][next_vel][next_action] - q_table_sarsa[pos][vel][action])
        
        # reassign state, action, reward
    state = next_state
    pos, vel = next_pos, next_vel
    action = next_action
    current_reward += reward
    
    # update epsilon
    if epsilon > 0:
        epsilon*= (n_eps - 1)/n_eps
    if ep % interval == 0:
        print('Game no.: ', ep, 'epsilon: ', epsilon, 'with reward: ', current_reward)
        rewards_sarsa.append(current_reward)
env.close()
# Out:
# Game no.:  100000 epsilon:  0.19919960985670956 with reward:  -1.0
# Game no.:  100000 epsilon:  0.19919761788053078 with reward:  -2.0
# Game no.:  100000 epsilon:  0.19919562592427154 with reward:  -3.0
# Game no.:  100000 epsilon:  0.19919363398793166 with reward:  -4.0
# Game no.:  100000 epsilon:  0.19919164207151097 with reward:  -5.0
# Game no.:  100000 epsilon:  0.19918965017500923 with reward:  -6.0
# Game no.:  100000 epsilon:  0.19918765829842625 with reward:  -7.0
# Game no.:  100000 epsilon:  0.19918566644176183 with reward:  -8.0
# Game no.:  100000 epsilon:  0.1991836746050158 with reward:  -9.0
# Game no.:  100000 epsilon:  0.19918168278818793 with reward:  -10.0
# Game no.:  100000 epsilon:  0.19917969099127802 with reward:  -11.0
# Game no.:  100000 epsilon:  0.19917769921428588 with reward:  -12.0
# Game no.:  100000 epsilon:  0.19917570745721133 with reward:  -13.0
# Game no.:  100000 epsilon:  0.19917371572005413 with reward:  -14.0
# Game no.:  100000 epsilon:  0.1991717240028141 with reward:  -15.0
# Game no.:  100000 epsilon:  0.19916973230549107 with reward:  -16.0
# Game no.:  100000 epsilon:  0.1991677406280848 with reward:  -17.0
# Game no.:  100000 epsilon:  0.19916574897059508 with reward:  -18.0
# Game no.:  100000 epsilon:  0.19916375733302177 with reward:  -19.0
# Game no.:  100000 epsilon:  0.19916176571536462 with reward:  -20.0
# Game no.:  100000 epsilon:  0.19915977411762345 with reward:  -21.0
# Game no.:  100000 epsilon:  0.19915778253979807 with reward:  -22.0
# Game no.:  100000 epsilon:  0.19915579098188826 with reward:  -23.0
# Game no.:  100000 epsilon:  0.19915379944389383 with reward:  -24.0
# Game no.:  100000 epsilon:  0.19915180792581458 with reward:  -25.0
# Game no.:  100000 epsilon:  0.1991498164276503 with reward:  -26.0
# Game no.:  100000 epsilon:  0.19914782494940084 with reward:  -27.0
# Game no.:  100000 epsilon:  0.19914583349106593 with reward:  -28.0
# Game no.:  100000 epsilon:  0.1991438420526454 with reward:  -29.0
# Game no.:  100000 epsilon:  0.19914185063413908 with reward:  -30.0
# Game no.:  100000 epsilon:  0.19913985923554675 with reward:  -31.0
# Game no.:  100000 epsilon:  0.19913786785686818 with reward:  -32.0
# Game no.:  100000 epsilon:  0.19913587649810321 with reward:  -33.0
# Game no.:  100000 epsilon:  0.19913388515925162 with reward:  -34.0
# Game no.:  100000 epsilon:  0.19913189384031324 with reward:  -35.0
# Game no.:  100000 epsilon:  0.19912990254128785 with reward:  -36.0
# Game no.:  100000 epsilon:  0.19912791126217524 with reward:  -37.0
# Game no.:  100000 epsilon:  0.19912592000297522 with reward:  -38.0
# Game no.:  100000 epsilon:  0.1991239287636876 with reward:  -39.0
# Game no.:  100000 epsilon:  0.19912193754431215 with reward:  -40.0
# Game no.:  100000 epsilon:  0.19911994634484873 with reward:  -41.0
# Game no.:  100000 epsilon:  0.1991179551652971 with reward:  -42.0
# Game no.:  100000 epsilon:  0.19911596400565704 with reward:  -43.0
# Game no.:  100000 epsilon:  0.19911397286592838 with reward:  -44.0
# Game no.:  100000 epsilon:  0.19911198174611094 with reward:  -45.0
# Game no.:  100000 epsilon:  0.1991099906462045 with reward:  -46.0
# Game no.:  100000 epsilon:  0.19910799956620884 with reward:  -47.0
# Game no.:  100000 epsilon:  0.19910600850612378 with reward:  -48.0
# Game no.:  100000 epsilon:  0.19910401746594913 with reward:  -49.0
# Game no.:  100000 epsilon:  0.1991020264456847 with reward:  -50.0
# Game no.:  100000 epsilon:  0.19910003544533025 with reward:  -51.0
# Game no.:  100000 epsilon:  0.1990980444648856 with reward:  -52.0
# Game no.:  100000 epsilon:  0.19909605350435058 with reward:  -53.0
# Game no.:  100000 epsilon:  0.19909406256372494 with reward:  -54.0
# Game no.:  100000 epsilon:  0.19909207164300852 with reward:  -55.0
# Game no.:  100000 epsilon:  0.1990900807422011 with reward:  -56.0
# Game no.:  100000 epsilon:  0.1990880898613025 with reward:  -57.0
# Game no.:  100000 epsilon:  0.19908609900031252 with reward:  -58.0
# Game no.:  100000 epsilon:  0.19908410815923094 with reward:  -59.0
# Game no.:  100000 epsilon:  0.19908211733805758 with reward:  -60.0
# Game no.:  100000 epsilon:  0.19908012653679222 with reward:  -61.0
# Game no.:  100000 epsilon:  0.19907813575543468 with reward:  -62.0
# Game no.:  100000 epsilon:  0.19907614499398474 with reward:  -63.0
# Game no.:  100000 epsilon:  0.19907415425244224 with reward:  -64.0
# Game no.:  100000 epsilon:  0.19907216353080695 with reward:  -65.0
# Game no.:  100000 epsilon:  0.19907017282907868 with reward:  -66.0
# Game no.:  100000 epsilon:  0.19906818214725722 with reward:  -67.0
# Game no.:  100000 epsilon:  0.19906619148534238 with reward:  -68.0
# Game no.:  100000 epsilon:  0.19906420084333395 with reward:  -69.0
# Game no.:  100000 epsilon:  0.19906221022123174 with reward:  -70.0
# Game no.:  100000 epsilon:  0.19906021961903556 with reward:  -71.0
# Game no.:  100000 epsilon:  0.1990582290367452 with reward:  -72.0
# Game no.:  100000 epsilon:  0.19905623847436046 with reward:  -73.0
# Game no.:  100000 epsilon:  0.19905424793188115 with reward:  -74.0
# Game no.:  100000 epsilon:  0.19905225740930707 with reward:  -75.0
# Game no.:  100000 epsilon:  0.19905026690663802 with reward:  -76.0
# Game no.:  100000 epsilon:  0.1990482764238738 with reward:  -77.0
# Game no.:  100000 epsilon:  0.1990462859610142 with reward:  -78.0
# Game no.:  100000 epsilon:  0.19904429551805902 with reward:  -79.0
# Game no.:  100000 epsilon:  0.1990423050950081 with reward:  -80.0
# Game no.:  100000 epsilon:  0.19904031469186118 with reward:  -81.0
# Game no.:  100000 epsilon:  0.1990383243086181 with reward:  -82.0
# Game no.:  100000 epsilon:  0.19903633394527864 with reward:  -83.0
# Game no.:  100000 epsilon:  0.19903434360184263 with reward:  -84.0
# Game no.:  100000 epsilon:  0.19903235327830987 with reward:  -85.0
# Game no.:  100000 epsilon:  0.19903036297468013 with reward:  -86.0
# Game no.:  100000 epsilon:  0.19902837269095322 with reward:  -87.0
# Game no.:  100000 epsilon:  0.19902638242712897 with reward:  -88.0
# Game no.:  100000 epsilon:  0.19902439218320714 with reward:  -89.0
# Game no.:  100000 epsilon:  0.19902240195918755 with reward:  -90.0
# Game no.:  100000 epsilon:  0.19902041175507001 with reward:  -91.0
# Game no.:  100000 epsilon:  0.1990184215708543 with reward:  -92.0
# Game no.:  100000 epsilon:  0.19901643140654027 with reward:  -93.0
# Game no.:  100000 epsilon:  0.19901444126212767 with reward:  -94.0
# Game no.:  100000 epsilon:  0.19901245113761631 with reward:  -95.0
# Game no.:  100000 epsilon:  0.199010461033006 with reward:  -96.0
# Game no.:  100000 epsilon:  0.19900847094829652 with reward:  -97.0
# Game no.:  100000 epsilon:  0.19900648088348769 with reward:  -98.0
# Game no.:  100000 epsilon:  0.19900449083857932 with reward:  -99.0
# Game no.:  100000 epsilon:  0.1990025008135712 with reward:  -100.0
# Game no.:  100000 epsilon:  0.19900051080846315 with reward:  -101.0
# Game no.:  100000 epsilon:  0.19899852082325492 with reward:  -102.0
# Game no.:  100000 epsilon:  0.19899653085794636 with reward:  -103.0
# Game no.:  100000 epsilon:  0.19899454091253724 with reward:  -104.0
# Game no.:  100000 epsilon:  0.19899255098702737 with reward:  -105.0
# Game no.:  100000 epsilon:  0.19899056108141655 with reward:  -106.0
# Game no.:  100000 epsilon:  0.1989885711957046 with reward:  -107.0
# Game no.:  100000 epsilon:  0.1989865813298913 with reward:  -108.0
# Game no.:  100000 epsilon:  0.1989845914839765 with reward:  -109.0
# Game no.:  100000 epsilon:  0.19898260165795992 with reward:  -110.0
# Game no.:  100000 epsilon:  0.1989806118518414 with reward:  -111.0
# Game no.:  100000 epsilon:  0.19897862206562075 with reward:  -112.0
# Game no.:  100000 epsilon:  0.19897663229929777 with reward:  -113.0
# Game no.:  100000 epsilon:  0.19897464255287226 with reward:  -114.0
# Game no.:  100000 epsilon:  0.198972652826344 with reward:  -115.0
# Game no.:  100000 epsilon:  0.19897066311971282 with reward:  -116.0
# Game no.:  100000 epsilon:  0.1989686734329785 with reward:  -117.0
# Game no.:  100000 epsilon:  0.19896668376614085 with reward:  -118.0
# Game no.:  100000 epsilon:  0.19896469411919968 with reward:  -119.0
# Game no.:  100000 epsilon:  0.19896270449215475 with reward:  -120.0
# Game no.:  100000 epsilon:  0.1989607148850059 with reward:  -121.0
# Game no.:  100000 epsilon:  0.19895872529775294 with reward:  -122.0
# Game no.:  100000 epsilon:  0.19895673573039566 with reward:  -123.0
# Game no.:  100000 epsilon:  0.19895474618293385 with reward:  -124.0
# Game no.:  100000 epsilon:  0.1989527566553673 with reward:  -125.0
# Game no.:  100000 epsilon:  0.19895076714769583 with reward:  -126.0
# Game no.:  100000 epsilon:  0.19894877765991925 with reward:  -127.0
# Game no.:  100000 epsilon:  0.19894678819203734 with reward:  -128.0
# Game no.:  100000 epsilon:  0.1989447987440499 with reward:  -129.0
# Game no.:  100000 epsilon:  0.19894280931595676 with reward:  -130.0
# Game no.:  100000 epsilon:  0.1989408199077577 with reward:  -131.0
# Game no.:  100000 epsilon:  0.19893883051945252 with reward:  -132.0
# Game no.:  100000 epsilon:  0.19893684115104102 with reward:  -133.0
# Game no.:  100000 epsilon:  0.198934851802523 with reward:  -134.0
# Game no.:  100000 epsilon:  0.19893286247389827 with reward:  -135.0
# Game no.:  100000 epsilon:  0.19893087316516664 with reward:  -136.0
# Game no.:  100000 epsilon:  0.19892888387632787 with reward:  -137.0
# Game no.:  100000 epsilon:  0.1989268946073818 with reward:  -138.0
# Game no.:  100000 epsilon:  0.19892490535832824 with reward:  -139.0
# Game no.:  100000 epsilon:  0.19892291612916696 with reward:  -140.0
# Game no.:  100000 epsilon:  0.19892092691989777 with reward:  -141.0
# Game no.:  100000 epsilon:  0.19891893773052047 with reward:  -142.0
# Game no.:  100000 epsilon:  0.19891694856103487 with reward:  -143.0
# Game no.:  100000 epsilon:  0.19891495941144077 with reward:  -144.0
# Game no.:  100000 epsilon:  0.19891297028173796 with reward:  -145.0
# Game no.:  100000 epsilon:  0.19891098117192627 with reward:  -146.0
# Game no.:  100000 epsilon:  0.19890899208200546 with reward:  -147.0
# Game no.:  100000 epsilon:  0.19890700301197536 with reward:  -148.0
# Game no.:  100000 epsilon:  0.19890501396183577 with reward:  -149.0
# Game no.:  100000 epsilon:  0.19890302493158646 with reward:  -150.0
# Game no.:  100000 epsilon:  0.19890103592122726 with reward:  -151.0
# Game no.:  100000 epsilon:  0.19889904693075797 with reward:  -152.0
# Game no.:  100000 epsilon:  0.19889705796017837 with reward:  -153.0
# Game no.:  100000 epsilon:  0.19889506900948828 with reward:  -154.0
# Game no.:  100000 epsilon:  0.1988930800786875 with reward:  -155.0
# Game no.:  100000 epsilon:  0.19889109116777584 with reward:  -156.0
# Game no.:  100000 epsilon:  0.19888910227675308 with reward:  -157.0
# Game no.:  100000 epsilon:  0.19888711340561904 with reward:  -158.0
# Game no.:  100000 epsilon:  0.19888512455437352 with reward:  -159.0
# Game no.:  100000 epsilon:  0.1988831357230163 with reward:  -160.0
# Game no.:  100000 epsilon:  0.1988811469115472 with reward:  -161.0
# Game no.:  100000 epsilon:  0.198879158119966 with reward:  -162.0
# Game no.:  100000 epsilon:  0.19887716934827254 with reward:  -163.0
# Game no.:  100000 epsilon:  0.19887518059646658 with reward:  -164.0
# Game no.:  100000 epsilon:  0.19887319186454794 with reward:  -165.0
# Game no.:  100000 epsilon:  0.1988712031525164 with reward:  -166.0
# Game no.:  100000 epsilon:  0.1988692144603718 with reward:  -167.0
# Game no.:  100000 epsilon:  0.19886722578811394 with reward:  -168.0
# Game no.:  100000 epsilon:  0.19886523713574258 with reward:  -169.0
# Game no.:  100000 epsilon:  0.19886324850325757 with reward:  -170.0
# Game no.:  100000 epsilon:  0.19886125989065867 with reward:  -171.0
# Game no.:  100000 epsilon:  0.1988592712979457 with reward:  -172.0
# Game no.:  100000 epsilon:  0.19885728272511846 with reward:  -173.0
# Game no.:  100000 epsilon:  0.19885529417217676 with reward:  -174.0
# Game no.:  100000 epsilon:  0.19885330563912038 with reward:  -175.0
# Game no.:  100000 epsilon:  0.19885131712594914 with reward:  -176.0
# Game no.:  100000 epsilon:  0.19884932863266283 with reward:  -177.0
# Game no.:  100000 epsilon:  0.19884734015926125 with reward:  -178.0
# Game no.:  100000 epsilon:  0.19884535170574422 with reward:  -179.0
# Game no.:  100000 epsilon:  0.1988433632721115 with reward:  -180.0
# Game no.:  100000 epsilon:  0.19884137485836292 with reward:  -181.0
# Game no.:  100000 epsilon:  0.19883938646449828 with reward:  -182.0
# Game no.:  100000 epsilon:  0.1988373980905174 with reward:  -183.0
# Game no.:  100000 epsilon:  0.19883540973642005 with reward:  -184.0
# Game no.:  100000 epsilon:  0.19883342140220606 with reward:  -185.0
# Game no.:  100000 epsilon:  0.19883143308787518 with reward:  -186.0
# Game no.:  100000 epsilon:  0.19882944479342726 with reward:  -187.0
# Game no.:  100000 epsilon:  0.19882745651886208 with reward:  -188.0
# Game no.:  100000 epsilon:  0.19882546826417943 with reward:  -189.0
# Game no.:  100000 epsilon:  0.19882348002937916 with reward:  -190.0
# Game no.:  100000 epsilon:  0.19882149181446102 with reward:  -191.0
# Game no.:  100000 epsilon:  0.19881950361942483 with reward:  -192.0
# Game no.:  100000 epsilon:  0.1988175154442704 with reward:  -193.0
# Game no.:  100000 epsilon:  0.1988155272889975 with reward:  -194.0
# Game no.:  100000 epsilon:  0.198813539153606 with reward:  -195.0
# Game no.:  100000 epsilon:  0.19881155103809564 with reward:  -196.0
# Game no.:  100000 epsilon:  0.19880956294246624 with reward:  -197.0
# Game no.:  100000 epsilon:  0.19880757486671757 with reward:  -198.0
# Game no.:  100000 epsilon:  0.19880558681084948 with reward:  -199.0
# Game no.:  100000 epsilon:  0.19880359877486173 with reward:  -200.0
